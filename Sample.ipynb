# %%
import pandas as pd

logon = pd.read_csv("logon.csv")
device = pd.read_csv("device.csv")
file1 = pd.read_csv("file.csv")

# %%
print(logon.shape)
print(device.shape)
print(file1.shape)
# Out:
# (854859, 5)
# (405380, 5)
# (445581, 6)

# %%
sample_logon = logon.sample(3000, random_state=42)
sample_device = device.sample(3000, random_state=42)
sample_file = file1.sample(3000, random_state=42)

# %%
sample_logon.to_csv("data/sample_logon.csv", index=False)
sample_device.to_csv("data/sample_device.csv", index=False)
sample_file.to_csv("data/sample_file.csv", index=False)

# %%
logon = pd.read_csv("data/sample_logon.csv")
device = pd.read_csv("data/sample_device.csv")
file1 = pd.read_csv("data/sample_file.csv")
